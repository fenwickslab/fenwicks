# %% [markdown]
# <a href="https://colab.research.google.com/github/fenwickslab/fenwicks/blob/master/tutorials/tutorial2_cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue May 14 17:40:44 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.56       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    18W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -qq -U cufflinks

# %%
import numpy as np
import tensorflow as tf
import os

# %%
if tf.io.gfile.exists('./fenwicks'):
  tf.io.gfile.rmtree('./fenwicks')
# !git clone https://github.com/fenwickslab/fenwicks.git

import fenwicks as fw
# Out:
# Cloning into 'fenwicks'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 1403 (delta 12), reused 14 (delta 4), pack-reused 1378
# Receiving objects: 100% (1403/1403), 36.35 MiB | 25.79 MiB/s, done.
# Resolving deltas: 100% (854/854), done.
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
BATCH_SIZE = 512 #@param ["512", "256", "128"] {type:"raw"}
MOMENTUM = 0.9 #@param ["0.9", "0.95", "0.975"] {type:"raw"}
WEIGHT_DECAY = 0.0005 #@param ["0.000125", "0.00025", "0.0005"] {type:"raw"}
LEARNING_RATE = 0.4 #@param ["0.4", "0.2", "0.1"] {type:"raw"}
EPOCHS = 24 #@param {type:"slider", min:0, max:100, step:1}
WARMUP = 5 #@param {type:"slider", min:0, max:24, step:1}
BUCKET = '.'
PROJECT = 'tutorial2'
VALID_BATCH_SIZE = 1000
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
data_dir, work_dir = fw.io.get_project_dirs(BUCKET, PROJECT)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
n_train, n_test = X_train.shape[0], X_test.shape[0]
img_size = X_train.shape[1]
n_classes = y_train.max() + 1
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
fw.plt.plot_counts_pie(y_train.reshape(-1))
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# <div id="17bd3e99-71d8-43a0-a494-a0c90f5c2029" style="height: 350px; width: 350px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("17bd3e99-71d8-43a0-a494-a0c90f5c2029", [{"hole": 0.2, "labels": [6, 9, 4, 1, 2, 7, 8, 3, 5, 0], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.05, "values": [5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000], "type": "pie"}], {"height": 350, "margin": {"b": 0, "l": 50, "r": 0, "t": 0}, "width": 350}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script>

# %%
X_train_mean = np.mean(X_train, axis=(0,1,2))
X_train_std = np.std(X_train, axis=(0,1,2))
X_train = (X_train - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
train_fn = os.path.join(data_dir, "train.tfrec")
test_fn = os.path.join(data_dir, "test.tfrec")

fw.data.numpy_tfrecord(train_fn, X_train, y_train)
fw.data.numpy_tfrecord(test_fn, X_test, y_test)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# INFO:tensorflow:Output file already exists. Skipping.
# INFO:tensorflow:Output file already exists. Skipping.

# %%
def parser_train(tfexample):
  x, y = fw.data.tfexample_numpy_image_parser(tfexample, img_size, img_size)
  x = fw.transform.random_pad_crop(x, 4)
  x = fw.transform.random_flip(x)
  x = fw.transform.cutout(x, 8, 8)
  return x, y

parser_test = lambda x: fw.data.tfexample_numpy_image_parser(x, img_size, img_size)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
train_input_func = lambda params: fw.data.tfrecord_ds(train_fn, parser_train, batch_size=params['batch_size'], training=True)
eval_input_func = lambda params: fw.data.tfrecord_ds(test_fn, parser_test, batch_size=params['batch_size'], training=False)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
converter = fw.transform.tfm_reverse_standard_scaler(X_train_mean/255, X_train_std/255)
fw.anim.show_input_func(eval_input_func, converter=converter)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgee9f682a25b34bf4b6db6db161839e49">
#     <br>
#     <input id="_anim_slideree9f682a25b34bf4b6db6db161839e49" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animee9f682a25b34bf4b6db6db161839e49.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animee9f682a25b34bf4b6db6db161839e49.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animee9f682a25b34bf4b6db6db161839e49.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animee9f682a25b34bf4b6db6db161839e49.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animee9f682a25b34bf4b6db6db161839e49.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animee9f682a25b34bf4b6db6db161839e49.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animee9f682a25b34bf4b6db6db161839e49.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animee9f682a25b34bf4b6db6db161839e49.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animee9f682a25b34bf4b6db6db161839e49.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animee9f682a25b34bf4b6db6db161839e49.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectee9f682a25b34bf4b6db6db161839e49" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgee9f682a25b34bf4b6db6db161839e49";
#     var slider_id = "_anim_slideree9f682a25b34bf4b6db6db161839e49";
#     var loop_select_id = "_anim_loop_selectee9f682a25b34bf4b6db6db161839e49";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAFDdJREFUeJztndtvXOd1xfe5zYVz4fAyIkVJlETJ\
# ku24iO3EThO4tREgLRygDwUCpK/9A4r+PQUKp0BfihRBWhRpUaBIYLRV01pWLNe2ZN1IyyJFkeJw\
# OJzrmXPpg1/32kBhbPhl/R6/jW/OmXPOmgOsb8/6gvf+8tVSAIEU6ngljtEUkSiEpXQ2g7WsmKvj\
# 1aQC5+Slfn4iImUBv5YEYa6Oh/jUpcgasBaK/nkiInEyVccjwdcwiPC553kGa1muX4+8COAcMc4j\
# M+bNQM24hJIX+H4FIT5WmurPRp4Z1xA8uyL2/UrBNRzhKTJOcdG6HoSQrwkFRogjFBghjlBghDhC\
# gRHiCAVGiCNxamisKCZ6wbDHKzm2syOJjDP5/1vnhhMrEuOJszTVCyE+v7jAnxcYqxYx+Mgw161n\
# ERGZ4+WM0rCY80I/WCo1PCeqwloKPk9EZJ6D65Hj8wtKvMRQM+5XAp7RMMbLGUVmXF/B5yHg+paC\
# lxEiY2mKbzBCHKHACHGEAiPEEQqMEEcoMEIciYvCclR0N6s0Gk4DwynMkXsnIlFd17rVtGmYN5IX\
# 2M2qJok6nok+/tXn4e8VGsfK5notEOyAhaXhWIa4+Vki3S2c5Ngp3O9ht22c4nMcnurzrEbadg1f\
# w4pxn1uNujper+LnMA+MZ810BPVzxE+GSJYb99KYRwj5mlBghDhCgRHiCAVGiCMUGCGOUGCEOBIn\
# BW4slVC3HwOQnyEiUgsN2z82siFAV29oNIEaTreIkckhIP8hruh2sIjI+sVrsHZ68hzWDo/G6ngl\
# wnZ7GBgNuEYOxVj087+zg89PasuwNI9w43ba0pcEhv0enLP3rA9rzRr+XjmYt7mGr+FyE1/DmpUp\
# AxqBq8ajWxhLE3yDEeIIBUaIIxQYIY5QYIQ4QoER4ggFRogjsRidxZJ01OHQmDO3IosjbOGnud79\
# XImx3Zpn2B4tSyPruNTPv5rg35vv/eiPYO3Wf96Atd3+kTo+yg1b2ojp3nlyCGvbe7vqeHXxLJxz\
# Yf0yrBWVFqzNE/2+JI0unJPNhrB29GwP1uqL+lLCl8NncM4URGCLiKy1cW/8QqJ30+eZvtwiAlez\
# vqrhEiHk60KBEeIIBUaIIxQYIY5QYIQ4QoER4kg8DbEVOxgvqONZhjvwlxvYim9Hxk6QoDW+mOPw\
# ksCwR3MjzCcCnfvjyTGc85t/+gdY2+/j63Fwqh/ri118rJ2nX8JaVG/CWh611fFmexXOSRbw50VV\
# /O+CPNDt7FqAlxieH4EodhFZv7AJa9PJSB3f3sY2/fGJvrOoiEgU4O98savXksjIaTdCoPgGI8QR\
# CowQRygwQhyhwAhxhAIjxJH4+QTHGfdSvdn3/RvvwzkvXcMu0g9fxm5WB3RMlkZDb4B2txORMDRi\
# sEsQ+2z83Gw/3oa13hg3JJcLS+p41DLcu+kprNU7i7CWTnXnLA2MWOolfL/aTXyOh/tP1fHTY5zJ\
# 0Uxwg3NtATuWj3t6pkjSOgPnHOw/hrXGM3x919ogptvaZRE8TyJ8gxHiCgVGiCMUGCGOUGCEOEKB\
# EeIIBUaII3HcxpkMo56uv6yCcxeOR9g6H831uGURkVaiN/WWIMpYRCQydhaMYr1RWURklupW7IHe\
# UyoiIkeneLkAZUaIiCx19SbWYTGAc1ZABLaI3YCbVvRrOBthW3o2xOexdAYvq0zALqHP5rihNynx\
# csaghzMvBOwgOhniGxZX8P0/PMWN1k9Bk/ClLn6uI2ZyEPLNQIER4ggFRogjFBghjlBghDhCgRHi\
# SHzt29+DxSf/dVcdb3SwTf/m9/HnNaIdWJuPdSs5iHBXvCRGZkSp/xNARKR15oI6

# %%
def build_nn(c=64, weight=0.125):
  model = fw.Sequential()
  model.add(fw.layers.ConvBN(c, **fw.layers.PYTORCH_PARAMS))
  model.add(fw.layers.ConvResBlk(c*2, res_convs=2, **fw.layers.PYTORCH_PARAMS))
  model.add(fw.layers.ConvBlk(c*4, **fw.layers.PYTORCH_PARAMS))
  model.add(fw.layers.ConvResBlk(c*8, res_convs=2, **fw.layers.PYTORCH_PARAMS))
  model.add(tf.keras.layers.GlobalMaxPool2D())
  model.add(fw.layers.Classifier(n_classes, kernel_initializer=fw.layers.init_pytorch, weight=weight))
  return model
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
steps_per_epoch = n_train // BATCH_SIZE
total_steps = steps_per_epoch * EPOCHS
warmup_steps = steps_per_epoch * WARMUP
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
lr_decay = fw.train.linear_decay()
lr_func = fw.train.one_cycle_lr(LEARNING_RATE/BATCH_SIZE, total_steps, warmup_steps, lr_decay)
fw.plt.plot_lr_func(lr_func, total_steps)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/learning_rate_decay_v2.py:321: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# <div id="b977560a-6b1a-45da-aebd-bd2774e1682c" style="height: 350px; width: 350px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b977560a-6b1a-45da-aebd-bd2774e1682c", [{"y": [0.0, 1.6108248246382573e-06, 3.2216496492765145e-06, 4.8324745876016095e-06, 6.443299298553029e-06, 8.054124009504449e-06, 9.664949175203219e-06, 1.1275773431407288e-05, 1.2886598597106058e-05, 1.4497423762804829e-05, 1.6108248019008897e-05, 1.7719072275212966e-05, 1.9329898350406438e-05, 2.0940722606610507e-05, 2.2551546862814575e-05, 2.4162372938008048e-05, 2.5773197194212116e-05, 2.7384021450416185e-05, 2.8994847525609657e-05, 3.0605671781813726e-05, 3.2216496038017794e-05, 3.382732029422186e-05, 3.543814455042593e-05, 3.704897244460881e-05, 3.8659796700812876e-05, 4.0270620957016945e-05, 4.1881445213221014e-05, 4.349226946942508e-05, 4.510309372562915e-05, 4.671392161981203e-05, 4.8324745876016095e-05, 4.9935570132220164e-05, 5.154639438842423e-05, 5.31572186446283e-05, 5.476804290083237e-05, 5.637886715703644e-05, 5.7989695051219314e-05, 5.960051930742338e-05, 6.121134356362745e-05, 6.282216781983152e-05, 6.443299207603559e-05, 6.604381633223966e-05, 6.765464058844373e-05, 6.92654648446478e-05, 7.087628910085186e-05, 7.248712063301355e-05, 7.409794488921762e-05, 7.570876914542168e-05, 7.731959340162575e-05, 7.893041765782982e-05, 8.054124191403389e-05, 8.215206617023796e-05, 8.376289042644203e-05, 8.53737146826461e-05, 8.698453893885016e-05, 8.859536319505423e-05, 9.02061874512583e-05, 9.181701170746237e-05, 9.342784323962405e-05, 9.503866749582812e-05, 9.664949175203219e-05, 9.826031600823626e-05, 9.987114026444033e-05, 0.0001014819645206444, 0.00010309278877684847, 0.00010470361303305253, 0.0001063144372892566, 0.00010792526154546067, 0.00010953608580166474, 0.00011114691005786881, 0.00011275773431407288, 0.00011436856584623456, 0.00011597939010243863, 0.0001175902143586427, 0.00011920103861484677, 0.00012081186287105083, 0.0001224226871272549, 0.00012403351138345897, 0.00012564433563966304, 0.0001272551598958671, 0.00012886598415207118, 0.00013047680840827525, 0.00013208763266447932, 0.00013369845692068338, 0.00013530928117688745, 0.00013692010543309152, 0.0001385309296892956, 0.00014014175394549966, 0.00014175257820170373, 0.0001433634024579078, 0.0001449742412660271, 0.00014658506552223116, 0.00014819588977843523, 0.0001498067140346393, 0.00015141753829084337, 0.00015302836254704744, 0.0001546391868032515, 0.00015625001105945557, 0.00015786083531565964, 0.0001594716595718637, 0.00016108248382806778, 0.00016269330808427185, 0.00016430413234047592, 0.00016591495659667999, 0.00016752578085288405, 0.00016913660510908812, 0.0001707474293652922, 0.00017235825362149626, 0.00017396907787770033, 0.0001755799021339044, 0.00017719072639010847, 0.00017880155064631253, 0.0001804123749025166, 0.00018202319915872067, 0.00018363402341492474, 0.0001852448476711288, 0.0001868556864792481, 0.00018846651073545218, 0.00019007733499165624, 0.0001916881592478603, 0.00019329898350406438, 0.00019490980776026845, 0.00019652063201647252, 0.0001981314562726766, 0.00019974228052888066, 0.00020135310478508472, 0.0002029639290412888, 0.00020457475329749286, 0.00020618557755369693, 0.000207796401809901, 0.00020940722606610507, 0.00021101805032230914, 0.0002126288745785132, 0.00021423969883471727, 0.00021585052309092134, 0.0002174613473471254, 0.00021907217160332948, 0.00022068299585953355, 0.00022229382011573762, 0.00022390464437194169, 0.00022551546862814575, 0.00022712630743626505, 0.00022873713169246912, 0.0002303479559486732, 0.00023195878020487726, 0.00023356960446108133, 0.0002351804287172854, 0.00023679125297348946, 0.00023840207722969353, 0.0002400129014858976, 0.00024162372574210167, 0.00024323454999830574, 0.0002448453742545098, 0.00024645618395879865, 0.00024806702276691794, 0.00024967786157503724, 0.00025128867 ...

# %%
opt_func = fw.train.sgd_optimizer(lr_func, mom=MOMENTUM, wd=WEIGHT_DECAY*BATCH_SIZE)
model_func = fw.train.get_clf_model_func(build_nn, opt_func, reduction=tf.losses.Reduction.SUM)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
est = fw.train.get_tpu_estimator(steps_per_epoch, model_func, work_dir, trn_bs=BATCH_SIZE, val_bs=VALID_BATCH_SIZE)
est.train(train_input_func, steps=total_steps)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# WARNING:tensorflow:Estimator's model_fn (<function get_clf_model_func.<locals>.model_func at 0x7f33a862b950>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': './work/tutorial2/2019-05-14-17:41:05', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f33a85cc208>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=97, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=3, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# WARNING:tensorflow:eval_on_tpu ignored because use_tpu is False.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/losses/losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./work/tutorial2/2019-05-14-17:41:05/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.42384
# INFO:tensorflow:examples/sec: 2265.01
# INFO:tensorflow:global_step/sec: 4.38288
# INFO:tensorflow:examples/sec: 2244.04
# INFO:tensorflow:global_step/sec: 4.16935
# INFO:tensorflow:examples/sec: 2134.71
# INFO:tensorflow:global_step/sec: 4.28805
# INFO:tensorflow:examples/sec: 2195.48
# INFO:tensorflow:global_step/sec: 4.34395
# INFO:tensorflow:examples/sec: 2224.1
# INFO:tensorflow:global_step/sec: 4.28298
# INFO:tensorflow:examples/sec: 2192.88
# INFO:tensorflow:global_step/sec: 4.24727
# INFO:tensorflow:examples/sec: 2174.6
# INFO:tensorflow:global_step/sec: 4.3279
# INFO:tensorflow:examples/sec: 2215.89
# INFO:tensorflow:global_step/sec: 4.3969
# INFO:tensorflow:examples/sec: 2251.21
# INFO:tensorflow:global_step/sec: 4.36005
# INFO:tensorflow:examples/sec: 2232.35
# INFO:tensorflow:global_step/sec: 4.37934
# INFO:tensorflow:examples/sec: 2242.22
# INFO:tensorflow:global_step/sec: 4.27605
# INFO:tensorflow:examples/sec: 2189.34
# INFO:tensorflow:global_step/sec: 4.36162
# INFO:tensorflow:examples/sec: 2233.15
# INFO:tensorflow:global_step/sec: 4.30917
# INFO:tensorflow:examples/sec: 2206.3
# INFO:tensorflow:global_step/sec: 4.48345
# INFO:tensorflow:examples/sec: 2295.53
# INFO:tensorflow:global_step/sec: 4.34436
# INFO:tensorflow:examples/sec: 2224.31
# INFO:tensorflow:global_step/sec: 4.21498
# INFO:tensorflow:examples/sec: 2158.07
# INFO:tensorflow:global_step/sec: 4.40131
# INFO:tensorflow:examples/sec: 2253.47
# INFO:tensorflow:global_step/sec: 4.30104
# INFO:tensorflow:examples/sec: 2202.13
# INFO:tensorflow:global_step/sec: 4.34581
# INFO:tensorflow:examples/sec: 2225.05
# INFO:tensorflow:global_step/sec: 4.41607
# INFO:tensorflow:examples/sec: 2261.03
# INFO:tensorflow:global_step/sec: 4.28218
# INFO:tensorflow:examples/sec: 2192.48
# INFO:tensorflow:global_step/sec: 4.38395
# INFO:tensorflow:examples/sec: 2244.58
# INFO:tensorflow:Saving checkpoints for 2328 into ./work/tutorial2/2019-05-14-17:41:05/model.ckpt.
# INFO:tensorflow:Loss for final step: 22.217361.
# INFO:tensorflow:training_loop marked as finished

# %%
result = est.evaluate(eval_input_func, steps=n_test // VALID_BATCH_SIZE)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-14T17:50:13Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./work/tutorial2/2019-05-14-17:41:05/model.ckpt-2328
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2019-05-14-17:50:18
# INFO:tensorflow:Saving dict for global step 2328: accuracy = 0.9409, global_step = 2328, loss = 180.38521
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2328: ./work/tutorial2/2019-05-14-17:41:05/model.ckpt-2328
# INFO:tensorflow:evaluation_loop marked as finished

# %%
print(f'Test results: accuracy={result["accuracy"] * 100: .2f}%, loss={result["loss"]: .2f}.')
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# Test results: accuracy= 94.09%, loss= 180.39.

# %%
fw.io.create_clean_dir(work_dir)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
