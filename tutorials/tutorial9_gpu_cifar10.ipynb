# %% [markdown]
# <a href="https://colab.research.google.com/github/fenwickslab/fenwicks/blob/master/tutorials/tutorial9_gpu_cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu May 23 16:50:00 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0    30W /  70W |   3457MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !pip install -qq -U cufflinks

# %%
import numpy as np
import tensorflow as tf
import os

# %%
if tf.io.gfile.exists('./fenwicks'):
  tf.io.gfile.rmtree('./fenwicks')
# !git clone -q https://github.com/fenwickslab/fenwicks.git

import fenwicks as fw
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
BATCH_SIZE = 128 #@param ["512", "256", "128", "64"] {type:"raw"}
MOMENTUM = 0.9 #@param ["0.9", "0.95", "0.975"] {type:"raw"}
WEIGHT_DECAY = 0.000125 #@param ["0.000125", "0.00025", "0.0005"] {type:"raw"}
LEARNING_RATE = 0.4 #@param ["0.4", "0.2", "0.1"] {type:"raw"}
EPOCHS = 24 #@param {type:"slider", min:0, max:100, step:1}
WARMUP = 5 #@param {type:"slider", min:0, max:24, step:1}
ROOT_DIR = '.'
PROJECT = 'tutorial2'
VALID_BATCH_SIZE = 1000
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %% [markdown]
# The GPU can read data from a local directory, and write intermediate files to a local directory. So there's no need for Google Cloud Storage.

# %%
data_dir, work_dir = fw.io.get_project_dirs(ROOT_DIR, PROJECT)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
n_train, n_test = X_train.shape[0], X_test.shape[0]
img_size = X_train.shape[1]
n_classes = y_train.max() + 1
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 40s 0us/step

# %%
fw.plt.plot_counts_pie(y_train.reshape(-1))
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# <div id="7bda7f55-cd44-44dd-b562-dbfe451ed704" style="height: 350px; width: 350px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7bda7f55-cd44-44dd-b562-dbfe451ed704", [{"hole": 0.2, "labels": [6, 9, 4, 1, 2, 7, 8, 3, 5, 0], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.05, "values": [5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000], "type": "pie"}], {"height": 350, "margin": {"b": 0, "l": 50, "r": 0, "t": 0}, "width": 350}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script>

# %%
X_train_mean = np.mean(X_train, axis=(0,1,2))
X_train_std = np.std(X_train, axis=(0,1,2))
X_train = (X_train - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
train_fn = os.path.join(data_dir, "train.tfrec")
test_fn = os.path.join(data_dir, "test.tfrec")

fw.data.numpy_tfrecord(train_fn, X_train, y_train)
fw.data.numpy_tfrecord(test_fn, X_test, y_test)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))

# %%
def parser_train(tfexample):
  x, y = fw.data.tfexample_numpy_image_parser(tfexample, img_size, img_size)
  x = fw.transform.random_pad_crop(x, 4)
  x = fw.transform.random_flip(x)
  x = fw.transform.cutout(x, 8, 8)
  return x, y

parser_test = lambda x: fw.data.tfexample_numpy_image_parser(x, img_size, img_size)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
train_input_func = lambda params: fw.data.tfrecord_ds(train_fn, parser_train, batch_size=params['batch_size'], training=True)
eval_input_func = lambda params: fw.data.tfrecord_ds(test_fn, parser_test, batch_size=params['batch_size'], training=False)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %% [markdown]
# Here we divide the mean and std by 255, because Matpltlib requires each pixel value to be within [0, 1], when the pixel data type is float.

# %%
converter = fw.transform.tfm_reverse_standard_scaler(X_train_mean/255, X_train_std/255)
fw.anim.show_input_func(eval_input_func, converter=converter)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# <video width="216" height="216" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
def build_nn(c=64, weight=0.125):
  model = fw.Sequential()
  model.add(fw.layers.ConvBN(c, **fw.layers.PYTORCH_PARAMS))
  model.add(fw.layers.ConvResBlk(c*2, res_convs=2, **fw.layers.PYTORCH_PARAMS))
  model.add(fw.layers.ConvBlk(c*4, **fw.layers.PYTORCH_PARAMS))
  model.add(fw.layers.ConvResBlk(c*8, res_convs=2, **fw.layers.PYTORCH_PARAMS))
  model.add(tf.keras.layers.GlobalMaxPool2D())
  model.add(fw.layers.Classifier(n_classes, kernel_initializer=fw.layers.init_pytorch, weight=weight))
  return model
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
steps_per_epoch = n_train // BATCH_SIZE
total_steps = steps_per_epoch * EPOCHS
warmup_steps = steps_per_epoch * WARMUP
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
lr_decay = fw.train.linear_decay()
lr_func = fw.train.one_cycle_lr(LEARNING_RATE/BATCH_SIZE, total_steps, warmup_steps, lr_decay)
fw.plt.plot_lr_func(lr_func, total_steps)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/learning_rate_decay_v2.py:321: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# <div id="cfdb14e5-f03a-4a4d-91a4-3b8bc64ee74f" style="height: 350px; width: 350px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cfdb14e5-f03a-4a4d-91a4-3b8bc64ee74f", [{"y": [0.0, 1.6025641116357292e-06, 3.2051282232714584e-06, 4.80769222122035e-06, 6.410256446542917e-06, 8.012820217118133e-06, 9.6153844424407e-06, 1.1217948667763267e-05, 1.2820512893085834e-05, 1.44230771184084e-05, 1.6025640434236266e-05, 1.7628204659558833e-05, 1.92307688848814e-05, 2.0833333110203966e-05, 2.2435897335526533e-05, 2.40384615608491e-05, 2.5641025786171667e-05, 2.7243590011494234e-05, 2.88461542368168e-05, 3.0448718462139368e-05, 3.205128086847253e-05, 3.36538469127845e-05, 3.5256409319117665e-05, 3.6858975363429636e-05, 3.84615377697628e-05, 4.006410381407477e-05, 4.166666622040793e-05, 4.3269232264719903e-05, 4.487179467105307e-05, 4.647436071536504e-05, 4.80769231216982e-05, 4.967948916601017e-05, 5.1282051572343335e-05, 5.28846139786765e-05, 5.448718002298847e-05, 5.608974242932163e-05, 5.76923084736336e-05, 5.9294870879966766e-05, 6.0897436924278736e-05, 6.25000029685907e-05, 6.410256173694506e-05, 6.570512778125703e-05, 6.7307693825569e-05, 6.891025986988097e-05, 7.051281863823533e-05, 7.21153846825473e-05, 7.371795072685927e-05, 7.532051677117124e-05, 7.69230755395256e-05, 7.852564158383757e-05, 8.012820762814954e-05, 8.17307663965039e-05, 8.333333244081587e-05, 8.493589848512784e-05, 8.653846452943981e-05, 8.814102329779416e-05, 8.974358934210613e-05, 9.13461553864181e-05, 9.294872143073007e-05, 9.455128019908443e-05, 9.61538462433964e-05, 9.775641228770837e-05, 9.935897833202034e-05, 0.0001009615371003747, 0.00010256410314468667, 0.00010416666918899864, 0.000105769227957353, 0.00010737179400166497, 0.00010897436004597694, 0.00011057692609028891, 0.00011217948485864326, 0.00011378205090295523, 0.0001153846169472672, 0.00011698718299157917, 0.00011858974175993353, 0.0001201923078042455, 0.00012179487384855747, 0.00012339743261691183, 0.0001250000059371814, 0.00012660256470553577, 0.00012820512347389013, 0.0001298076967941597, 0.00013141025556251407, 0.00013301281433086842, 0.000134615387651138, 0
# INFO:tensorflow:global_step/sec: 16.0934
# INFO:tensorflow:examples/sec: 2059.96
# INFO:tensorflow:global_step/sec: 16.3106
# INFO:tensorflow:examples/sec: 2087.76
# INFO:tensorflow:global_step/sec: 16.2561
# INFO:tensorflow:examples/sec: 2080.78
# INFO:tensorflow:global_step/sec: 15.8795
# INFO:tensorflow:examples/sec: 2032.57
# INFO:tensorflow:global_step/sec: 15.4556
# INFO:tensorflow:examples/sec: 1978.31
# INFO:tensorflow:global_step/sec: 16.514
# INFO:tensorflow:examples/sec: 2113.8
# INFO:tensorflow:global_step/sec: 16.6777
# INFO:tensorflow:examples/sec: 2134.74
# INFO:tensorflow:global_step/sec: 16.4589
# INFO:tensorflow:examples/sec: 2106.74
# INFO:tensorflow:global_step/sec: 16.1302
# INFO:tensorflow:examples/sec: 2064.67
# INFO:tensorflow:global_step/sec: 15.9256
# INFO:tensorflow:examples/sec: 2038.48
# INFO:tensorflow:global_step/sec: 15.9277
# INFO:tensorflow:examples/sec: 2038.74
# INFO:tensorflow:global_step/sec: 16.0791
# INFO:tensorflow:examples/sec: 2058.12
# INFO:tensorflow:global_step/sec: 16.6555
# INFO:tensorflow:examples/sec: 2131.9
# INFO:tensorflow:global_step/sec: 16.4354
# INFO:tensorflow:examples/sec: 2103.73
# INFO:tensorflow:global_step/sec: 16.359
# INFO:tensorflow:examples/sec: 2093.95
# INFO:tensorflow:global_step/sec: 16.5109
# INFO:tensorflow:examples/sec: 2113.39
# INFO:tensorflow:global_step/sec: 15.7374
# INFO:tensorflow:examples/sec: 2014.38
# INFO:tensorflow:global_step/sec: 15.8141
# INFO:tensorflow:examples/sec: 2024.21
# INFO:tensorflow:global_step/sec: 16.3507
# INFO:tensorflow:examples/sec: 2092.89
# INFO:tensorflow:global_step/sec: 16.2682
# INFO:tensorflow:examples/sec: 2082.33
# INFO:tensorflow:Saving checkpoints for 9360 into ./work/tutorial2/2019-05-23-16:51:44/model.ckpt.
# INFO:tensorflow:Loss for final step: 12.81305.
# INFO:tensorflow:training_loop marked as finished

# %% [markdown]
# On the GPU, we get Out-Of-Memory (OOM) error if we set the validation batch size to the size of the validation dataset as in the case of TPU.

# %%
result = est.evaluate(eval_input_func, steps=n_test // VALID_BATCH_SIZE)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-23T17:01:32Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./work/tutorial2/2019-05-23-16:51:44/model.ckpt-9360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2019-05-23-17:01:36
# INFO:tensorflow:Saving dict for global step 9360: accuracy = 0.9398, global_step = 9360, loss = 181.37126
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9360: ./work/tutorial2/2019-05-23-16:51:44/model.ckpt-9360
# INFO:tensorflow:evaluation_loop marked as finished

# %%
print(f'Test results: accuracy={result["accuracy"] * 100: .2f}%, loss={result["loss"]: .2f}.')
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# Test results: accuracy= 93.98%, loss= 181.37.

# %%
fw.io.create_clean_dir(work_dir)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
